-- %%
SELECT * FROM misha_11.default.taxi_raw_records LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM misha_11.default.flagged_rides LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM misha_11.default.weekly_stats LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM misha_11.default.top_n LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>week</th><th>avg_amount</th><th>avg_distance</th><th>fare_amount</th><th>trip_distance</th><th>passenger_area</th></tr></thead><tbody><tr><td>2016-01-04T00:00:00Z</td><td>11.91</td><td>2.865</td><td>95.0</td><td>5.2</td><td>10009</td></tr><tr><td>2016-02-15T00:00:00Z</td><td>12.24</td><td>2.894</td><td>60.0</td><td>2.0</td><td>7311</td></tr><tr><td>2016-02-22T00:00:00Z</td><td>12.79</td><td>2.973</td><td>60.0</td><td>0.92</td><td>11422</td></tr></tbody></table></div>
